# %%
import pandas as pd
import childespy as chp 
import os 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Reinstalling childesr version 0.2.1
# --- Please select a CRAN mirror for use in this session ---
# Secure CRAN mirrors
#
#  1: 0-Cloud [https]
#  2: Australia (Canberra) [https]
#  3: Australia (Melbourne 1) [https]
#  4: Australia (Melbourne 2) [https]
#  5: Austria [https]
#  6: Belgium (Brussels) [https]
#  7: Brazil (PR) [https]
#  8: Brazil (SP 1) [https]
#  9: Brazil (SP 2) [https]
# 10: Bulgaria [https]
# 11: Canada (MB) [https]
# 12: Canada (ON 1) [https]
# 13: Canada (ON 2) [https]
# 14: Chile (Santiago) [https]
# 15: China (Beijing 2) [https]
# 16: China (Beijing 3) [https]
# 17: China (Hefei) [https]
# 18: China (Hong Kong) [https]
# 19: China (Guangzhou) [https]
# 20: China (Jinan) [https]
# 21: China (Lanzhou) [https]
# 22: China (Nanjing) [https]
# 23: China (Shanghai 2) [https]
# 24: China (Shenzhen) [https]
# 25: Colombia (Cali) [https]
# 26: Costa Rica [https]
# 27: Cyprus [https]
# 28: Czech Republic [https]
# 29: Denmark [https]
# 30: East Asia [https]
# 31: Ecuador (Cuenca) [https]
# 32: France (Lyon 1) [https]
# 33: France (Lyon 2) [https]
# 34: France (Marseille) [https]
# 35: France (Paris 1) [https]
# 36: Germany (Erlangen) [https]
# 37: Germany (Göttingen) [https]
# 38: Germany (Leipzig) [https]
# 39: Germany (Münster) [https]
# 40: Greece [https]
# 41: Iceland [https]
# 42: India (Bengaluru) [https]
# 43: India (Bhubaneswar) [https]
# 44: Indonesia (Banda Aceh) [https]
# 45: Iran (Mashhad) [https]
# 46: Italy (Milano) [https]
# 47: Italy (Padua) [https]
# 48: Japan (Yonezawa) [https]
# 49: Korea (Gyeongsan-si) [https]
# 50: Mexico (Mexico City) [https]
# 51: Mexico (Texcoco) [https]
# 52: Morocco [https]
# 53: Netherlands (Dronten) [https]
# 54: New Zealand [https]
# 55: Norway [https]
# 56: South Africa (Johannesburg) [https]
# 57: Spain (A Coruña) [https]
# 58: Spain (Madrid) [https]
# 59: Sweden (Umeå) [https]
# 60: Switzerland (Zurich 1) [https]
# 61: Taiwan (Taipei) [https]
# 62: Turkey (Denizli) [https]
# 63: Turkey (Istanbul) [https]
# 64: UK (Bristol) [https]
# 65: UK (London 1) [https]
# 66: USA (IA) [https]
# 67: USA (MI) [https]
# 68: USA (MO) [https]
# 69: USA (OH) [https]
# 70: USA (OR) [https]
# 71: USA (PA 1) [https]
# 72: USA (TN) [https]
# 73: United Arab Emirates [https]
# 74: Uruguay [https]
# 75: (other mirrors)
#
# Selection: 67
# R[write to console]: trying URL 'https://repo.miserver.it.umich.edu/cran/src/contrib/childesr_0.2.3.tar.gz'
#
# R[write to console]: Content type 'application/octet-stream'
# R[write to console]:  length 22865 bytes (22 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 22 KB

# %%
#chp.get_utterances(corpus="Providence", target_child = "alex")

# %%
#transcript_df = chp.get_sql_query("SELECT * FROM transcript WHERE corpus_name = 'Providence'")
#utt_df = chp.get_sql_query("SELECT * FROM utterance WHERE corpus_name = 'Providence'")

# %%
#chp.get_transcripts(collection_id=8)

# %%
#chp.get_transcripts(collection ='Other')['corpus_name'].unique()

# %% [markdown]
# compare integers for lookups

# %%
t_df = chp.get_transcripts(corpus = 'Providence')
# Out:
# R[write to console]: Using current database version: '2021.1'.

# %%
child_names = t_df['target_child_name'].unique()

# %% [markdown]
# Transcripts with no child name

# %%
t_df[t_df['target_child_name']=='None']
# Out:
#      transcript_id corpus_name language  date  \
# 2            43209  Providence      nan  None
# 314          43521  Providence      nan  None
#
#                                 filename target_child_name  target_child_age  \
# 2      Eng-NA/Providence/Alex/010700.xml              None               NaN
# 314  Eng-NA/Providence/Violet/030200.xml              None               NaN
#
#     target_child_sex collection_name                 pid  collection_id  \
# 2               None          Eng-NA  11312/a-00016830-1             21
# 314             None          Eng-NA  11312/a-00016829-1             21
#
#      corpus_id  target_child_id
# 2          336            23470
# 314        336            23470

# %% [markdown]
# Transcripts with `None` in their target_child_name can be ignored as those are dummy transcripts (hand-verified)

# %%
child_names = [c for c in child_names if c!='None']

# %%
child_names
# Out:
# ['Alex', 'Ethan', 'Lily', 'Naima', 'Violet', 'William']

# %%
utt_dfs = []
for child in child_names:
    utt_dfs.append(chp.get_utterances(corpus = 'Providence', target_child  = child))
# Out:
# R[write to console]: Using current database version: '2021.1'.
#
# R[write to console]: Getting data from 1 child in 1 corpus ...
#
# R[write to console]: Using current database version: '2021.1'.
#
# R[write to console]: Getting data from 1 child in 1 corpus ...
#
# R[write to console]: Using current database version: '2021.1'.
#
# R[write to console]: Getting data from 1 child in 1 corpus ...
#
# R[write to console]: Using current database version: '2021.1'.
#
# R[write to console]: Getting data from 1 child in 1 corpus ...
#
# R[write to console]: Using current database version: '2021.1'.
#
# R[write to console]: Getting data from 1 child in 1 corpus ...
#
# R[write to console]: Using current database version: '2021.1'.
#
# R[write to console]: Getting data from 1 child in 1 corpus ...

# %%
t_df
# Out:
#      transcript_id corpus_name language        date  \
# 1            43208  Providence      eng  2002-05-02
# 2            43209  Providence      nan        None
# 3            43210  Providence      eng  2002-05-16
# 4            43211  Providence      eng  2002-05-30
# 5            43212  Providence      eng  2002-06-18
# ..             ...         ...      ...         ...
# 362          43569  Providence      eng  2004-04-01
# 363          43570  Providence      eng  2004-04-29
# 364          43571  Providence      eng  2004-05-13
# 365          43572  Providence      eng  2004-06-01
# 366          43573  Providence      eng  2004-06-26
#
#                                  filename target_child_name  target_child_age  \
# 1       Eng-NA/Providence/Alex/010427.xml              Alex         16.887410
# 2       Eng-NA/Providence/Alex/010700.xml              None               NaN
# 3       Eng-NA/Providence/Alex/010512.xml              Alex         17.394608
# 4       Eng-NA/Providence/Alex/010526.xml              Alex         17.854576
# 5       Eng-NA/Providence/Alex/010614.xml              Alex         18.460338
# ..                                    ...               ...               ...
# 362  Eng-NA/Providence/William/030125.xml           William         37.822132
# 363  Eng-NA/Providence/William/030221.xml           William         38.690733
# 364  Eng-NA/Providence/William/030305.xml           William         39.165075
# 365  Eng-NA/Providence/William/030325.xml           William         39.822173
# 366  Eng-NA/Providence/William/030418.xml           William         40.592209
#
#     target_child_sex collection_name                 pid  collection_id  \
# 1               male          Eng-NA  11312/c-00040975-1             21
# 2               None          Eng-NA  11312/a-00016830-1             21
# 3               male          Eng-NA  11312/c-00040976-1             21
# 4               male          Eng-NA  11312/c-00040977-1             21
# 5               male          Eng-NA  11312/c-00040978-1             21
# ..               ...             ...                 ...            ...
# 362             male          Eng-NA  11312/c-00041334-1             21
# 363             male          Eng-NA  11312/c-00041335-1             21
# 364             male          Eng-NA  11312/c-00041336-1             21
# 365             male          Eng-NA  11312/c-00041337-1             21
# 366             male          Eng-NA  11312/c-00041338-1             21
#
#      corpus_id  target_child_id
# 1          336            23471
# 2          336            23470
# 3          336            23471
# 4          336            23471
# 5          336            23471
# ..         ...              ...
# 362        336            23530
# 363        336            23530
# 364        336            23530
# 365        336            23530
# 366        336            23530
#
# [366 rows x 13 columns]

# %%
#u_df

# %%
subset_info = t_df[['transcript_id','filename']]

# %%
subset_info
# Out:
#      transcript_id                              filename
# 1            43208     Eng-NA/Providence/Alex/010427.xml
# 2            43209     Eng-NA/Providence/Alex/010700.xml
# 3            43210     Eng-NA/Providence/Alex/010512.xml
# 4            43211     Eng-NA/Providence/Alex/010526.xml
# 5            43212     Eng-NA/Providence/Alex/010614.xml
# ..             ...                                   ...
# 362          43569  Eng-NA/Providence/William/030125.xml
# 363          43570  Eng-NA/Providence/William/030221.xml
# 364          43571  Eng-NA/Providence/William/030305.xml
# 365          43572  Eng-NA/Providence/William/030325.xml
# 366          43573  Eng-NA/Providence/William/030418.xml
#
# [366 rows x 2 columns]

# %% [markdown]
# Now merging actual transcript filenames with the ID

# %%
child_with_transcripts = []
for childdf in utt_dfs:
    merged_df = pd.merge(childdf, subset_info, on='transcript_id', how='left')
    child_with_transcripts.append(merged_df )

# %%
child_with_transcripts[0]
# Out:
#              id                                              gloss  \
# 0      17264832                         where do you want me to go
# 1      17264840       anywhere you'll feel comfortable um anywhere
# 2      17264848                               please don't do that
# 3      17264856                                            this is
# 4      17264864             go into the kitchen and check in about
# ...         ...                                                ...
# 72621  17398709                                                xxx
# 72622  17398722                                                xxx
# 72623  17398739  Alex can Mommy have your microphone please for...
# 72624  17398756                                go give it to Mommy
# 72625  17398769                                                xxx
#
#                                                     stem actual_phonology  \
# 0                             where do you want me to go
# 1                     anywhere you feel comfort anywhere
# 2                                      please do do that
# 3                                                this be
# 4                 go into the kitchen and check in about
# ...                                                  ...              ...
# 72621
# 72622
# 72623  Alex can Mommy have your microphone please for...
# 72624                                go give it to Mommy
# 72625
#
#       model_phonology               type language  num_morphemes  num_tokens  \
# 0                               question      eng              7           7
# 1                            declarative      eng              8           6
# 2                            declarative      eng              5           4
# 3                      self interruption      eng              3           2
# 4                      self interruption      eng              8           8
# ...               ...                ...      ...            ...         ...
# 72621                        declarative      eng    -2147483648           1
# 72622                        declarative      eng    -2147483648           1
# 72623                           question      eng              9           9
# 72624                        declarative      eng              5           5
# 72625                        declarative      eng    -2147483648           1
#
#        utterance_order  ... media_start media_end media_unit collection_name  \
# 0                    1  ...       0.000     7.830          s          Eng-NA
# 1                    2  ...         NaN       NaN       None          Eng-NA
# 2                    3  ...       7.830    10.888          s          Eng-NA
# 3                    4  ...      10.888    15.525          s          Eng-NA
# 4                    5  ...         NaN       NaN       None          Eng-NA
# ...                ...  ...         ...       ...        ...             ...
# 72621             2174  ...         NaN       NaN       None          Eng-NA
# 72622             2175  ...    3941.016  3945.158          s          Eng-NA
# 72623             2176  ...         NaN       NaN       None          Eng-NA
# 72624             2177  ...         NaN       NaN       None          Eng-NA
# 72625             2178  ...    3945.158  3948.171          s          Eng-NA
#
#       collection_id corpus_id  speaker_id target_child_id  transcript_id  \
# 0                21       336       23475           23471          43208
# 1                21       336       23473           23471          43208
# 2                21       336       23473           23471          43208
# 3                21       336       23473           23471          43208
# 4                21       336       23475           23471          43208
# ...             ...       ...         ...             ...            ...
# 72621            21       336       23475           23471          43259
# 72622            21       336       23471           23471          43259
# 72623            21       336       23473           23471          43259
# 72624            21       336       23479           23471          43259
# 72625            21       336       23471           23471          43259
#
#                                 filename
# 0      Eng-NA/Providence/Alex/010427.xml
# 1      Eng-NA/Providence/Alex/010427.xml
# 2      Eng-NA/Providence/Alex/010427.xml
# 3      Eng-NA/Providence/Alex/010427.xml
# 4      Eng-NA/Providence/Alex/010427.xml
# ...                                  ...
# 72621  Eng-NA/Providence/Alex/030516.xml
# 72622  Eng-NA/Providence/Alex/030516.xml
# 72623  Eng-NA/Providence/Alex/030516.xml
# 72624  Eng-NA/Providence/Alex/030516.xml
# 72625  Eng-NA/Providence/Alex/030516.xml
#
# [72626 rows x 28 columns]

# %% [markdown]
# ## Now concatenating all child dfs

# %%
full_merge = pd.concat([d for d in child_with_transcripts]).reset_index()

# %%
print('youngest child in providence: ', full_merge['target_child_age'].min())
print('oldest child in providence: ', full_merge['target_child_age'].max())
# Out:
# youngest child in providence:  11.131645413663525
# oldest child in providence:  48.06669541469024

# %%
import math 
start = math.floor(full_merge['target_child_age'].min()/6)
end = math.ceil(full_merge['target_child_age'].max()/6)

# %% [markdown]
# Is identity of child important in the split? currently, no

# %%
bin_edges = [6*i for i in range(start,end+1)]
bin_edges
# Out:
# [6, 12, 18, 24, 30, 36, 42, 48, 54]

# %%
labels = [str(bin_edges[i])+"-"+str(bin_edges[i+1]) for i in range(len(bin_edges)-1)]  # Define bin labels

# %%
labels
# Out:
# ['6-12', '12-18', '18-24', '24-30', '30-36', '36-42', '42-48', '48-54']

# %%
cuts = pd.cut(full_merge['target_child_age'], bins=bin_edges, labels=labels, include_lowest=True)

# %%
full_merge['bin_label'] = cuts

# %%
full_merge
# Out:
#         index        id                                         gloss  \
# 0           0  17264832                    where do you want me to go
# 1           1  17264840  anywhere you'll feel comfortable um anywhere
# 2           2  17264848                          please don't do that
# 3           3  17264856                                       this is
# 4           4  17264864        go into the kitchen and check in about
# ...       ...       ...                                           ...
# 460056  56367  17753088                                           xxx
# 460057  56368  17753090       xxx my lion Daddy I don't bring my lion
# 460058  56369  17753091                                come here Will
# 460059  56370  17753092                               yyy yyy yyy yyy
# 460060  56371  17753093                                          roar
#
#                                           stem  \
# 0                   where do you want me to go
# 1           anywhere you feel comfort anywhere
# 2                            please do do that
# 3                                      this be
# 4       go into the kitchen and check in about
# ...                                        ...
# 460056
# 460057        my lion Daddy I do bring my lion
# 460058                          come here Will
# 460059
# 460060                                    roar
#
#                              actual_phonology  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 460056                                      *
# 460057  * mə laɪɛn dædi aɪ don brɪŋ maɪ laɪɛn
# 460058
# 460059                      dɜ˞r dɛ dɜ˞r dɜ˞r
# 460060                                    rær
#
#                                   model_phonology               type language  \
# 0                                                           question      eng
# 1                                                        declarative      eng
# 2                                                        declarative      eng
# 3                                                  self interruption      eng
# 4                                                  self interruption      eng
# ...                                           ...                ...      ...
# 460056                                          *        declarative      eng
# 460057  * maɪ laɪən dædiː aɪ doʊnt bɹɪŋ maɪ laɪən        declarative      eng
# 460058                                                   declarative      eng
# 460059                                    * * * *        declarative      eng
# 460060                                        ɹɔɹ        declarative      eng
#
#         num_morphemes  num_tokens  ...  media_end media_unit collection_name  \
# 0                   7           7  ...      7.830          s          Eng-NA
# 1                   8           6  ...        NaN       None          Eng-NA
# 2                   5           4  ...     10.888          s          Eng-NA
# 3                   3           2  ...     15.525          s          Eng-NA
# 4                   8           8  ...        NaN       None          Eng-NA
# ...               ...         ...  ...        ...        ...             ...
# 460056    -2147483648           1  ...   1571.061          s          Eng-NA
# 460057              9           9  ...   1576.861          s          Eng-NA
# 460058              3           3  ...   1577.373          s          Eng-NA
# 460059    -2147483648           4  ...   1581.430          s          Eng-NA
# 460060              1           1  ...   1583.370          s          Eng-NA
#
#        collection_id corpus_id speaker_id target_child_id  transcript_id  \
# 0                 21       336      23475           23471          43208
# 1                 21       336      23473           23471          43208
# 2                 21       336      23473           23471          43208
# 3                 21       336      23473           23471          43208
# 4                 21       336      23475           23471          43208
# ...              ...       ...        ...             ...            ...
# 460056            21       336      23530           23530          43562
# 460057            21       336      23530           23530          43562
# 460058            21       336      23534           23530          43562
# 460059            21       336      23530           23530          43562
# 460060            21       336      23530           23530          43562
#
#                                     filename  bin_label
# 0          Eng-NA/Providence/Alex/010427.xml      12-18
# 1          Eng-NA/Providence/Alex/010427.xml      12-18
# 2          Eng-NA/Providence/Alex/010427.xml      12-18
# 3          Eng-NA/Providence/Alex/010427.xml      12-18
# 4          Eng-NA/Providence/Alex/010427.xml      12-18
# ...                                      ...        ...
# 460056  Eng-NA/Providence/William/020822.xml      30-36
# 460057  Eng-NA/Providence/William/020822.xml      30-36
# 460058  Eng-NA/Providence/William/020822.xml      30-36
# 460059  Eng-NA/Providence/William/020822.xml      30-36
# 460060  Eng-NA/Providence/William/020822.xml      30-36
#
# [460061 rows x 30 columns]

# %%
len(full_merge['transcript_id'].unique())
# Out:
# 364

# %%
full_merge[full_merge['transcript_id'] == 43562]['target_child_age']
# Out:
# 459279    32.723465
# 459280    32.723465
# 459281    32.723465
# 459282    32.723465
# 459283    32.723465
#             ...
# 460056    32.723465
# 460057    32.723465
# 460058    32.723465
# 460059    32.723465
# 460060    32.723465
# Name: target_child_age, Length: 782, dtype: float64

# %%
trans_ages = full_merge[['transcript_id','target_child_age','target_child_name']].drop_duplicates()

# %%
cuts_copy = pd.cut(trans_ages['target_child_age'], bins=bin_edges, labels=labels, include_lowest=True)
trans_ages['bin_label'] = cuts_copy

# %%
trans_ages
# Out:
#         transcript_id  target_child_age target_child_name bin_label
# 0               43208         16.887410              Alex     12-18
# 31              43210         17.394608              Alex     12-18
# 46              43211         17.854576              Alex     12-18
# 70              43212         18.460338              Alex     18-24
# 165             43213         19.230374              Alex     18-24
# ...               ...               ...               ...       ...
# 446930          43553         28.526253           William     24-30
# 447995          43572         39.822173           William     36-42
# 448854          43569         37.822132           William     36-42
# 454765          43550         27.230539           William     24-30
# 459279          43562         32.723465           William     30-36
#
# [364 rows x 4 columns]

# %% [markdown]
# ## Splitting transcripts from each bucket into TR/VA/TE (each bucket is a unique combination of name and age group)

# %%
age_child_prod = len(labels)*len(child_names)

# %%
transcripts_with_splits = []
seeds = [i for i in range(0, age_child_prod)]

i = 0
for binlabel in labels:
    for child in child_names:
        np.random.seed(seeds[i])
        #binlabel = labels[i]
        bin_df = trans_ages[(trans_ages['bin_label'] == binlabel) & (trans_ages['target_child_name'] == child)]
        nrows = len(bin_df)
        ntr = math.floor(nrows*0.8)
        nva = math.floor(nrows*0.1)
        nte = nrows - ntr - nva
        lab = ["TR"] * ntr + ["VA"] * nva + ["TE"] * nte
        lab_array = np.array(lab)
        np.random.shuffle(lab_array)
        bin_df['split'] = lab_array
        transcripts_with_splits.append(bin_df)
        i = i+1
# Out:
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array
# /tmp/ipykernel_3605748/3899444937.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bin_df['split'] = lab_array

# %%
transcripts_with_splits[1]
# Out:
#        transcript_id  target_child_age target_child_name bin_label split
# 72626          43260         11.131645             Ethan      6-12    TR
# 72714          43261         11.690178             Ethan      6-12    TE

# %%
trans_labelled = pd.concat([d for d in transcripts_with_splits]).reset_index()
trans_labelled
# Out:
#       index  transcript_id  target_child_age target_child_name bin_label split
# 0     72626          43260         11.131645             Ethan      6-12    TR
# 1     72714          43261         11.690178             Ethan      6-12    TE
# 2    246205          43390         11.854453             Naima      6-12    TE
# 3         0          43208         16.887410              Alex     12-18    TR
# 4        31          43210         17.394608              Alex     12-18    TR
# ..      ...            ...               ...               ...       ...   ...
# 359  390807          43527         44.756566            Violet     42-48    TR
# 360  394130          43529         47.789482            Violet     42-48    TE
# 361  399427          43526         43.723690            Violet     42-48    TR
# 362  400796          43528         46.592332            Violet     42-48    TR
# 363  239447          43389         48.066695              Lily     48-54    TE
#
# [364 rows x 6 columns]

# %%
full_merge
# Out:
#         index        id                                         gloss  \
# 0           0  17264832                    where do you want me to go
# 1           1  17264840  anywhere you'll feel comfortable um anywhere
# 2           2  17264848                          please don't do that
# 3           3  17264856                                       this is
# 4           4  17264864        go into the kitchen and check in about
# ...       ...       ...                                           ...
# 460056  56367  17753088                                           xxx
# 460057  56368  17753090       xxx my lion Daddy I don't bring my lion
# 460058  56369  17753091                                come here Will
# 460059  56370  17753092                               yyy yyy yyy yyy
# 460060  56371  17753093                                          roar
#
#                                           stem  \
# 0                   where do you want me to go
# 1           anywhere you feel comfort anywhere
# 2                            please do do that
# 3                                      this be
# 4       go into the kitchen and check in about
# ...                                        ...
# 460056
# 460057        my lion Daddy I do bring my lion
# 460058                          come here Will
# 460059
# 460060                                    roar
#
#                              actual_phonology  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 460056                                      *
# 460057  * mə laɪɛn dædi aɪ don brɪŋ maɪ laɪɛn
# 460058
# 460059                      dɜ˞r dɛ dɜ˞r dɜ˞r
# 460060                                    rær
#
#                                   model_phonology               type language  \
# 0                                                           question      eng
# 1                                                        declarative      eng
# 2                                                        declarative      eng
# 3                                                  self interruption      eng
# 4                                                  self interruption      eng
# ...                                           ...                ...      ...
# 460056                                          *        declarative      eng
# 460057  * maɪ laɪən dædiː aɪ doʊnt bɹɪŋ maɪ laɪən        declarative      eng
# 460058                                                   declarative      eng
# 460059                                    * * * *        declarative      eng
# 460060                                        ɹɔɹ        declarative      eng
#
#         num_morphemes  num_tokens  ...  media_end media_unit collection_name  \
# 0                   7           7  ...      7.830          s          Eng-NA
# 1                   8           6  ...        NaN       None          Eng-NA
# 2                   5           4  ...     10.888          s          Eng-NA
# 3                   3           2  ...     15.525          s          Eng-NA
# 4                   8           8  ...        NaN       None          Eng-NA
# ...               ...         ...  ...        ...        ...             ...
# 460056    -2147483648           1  ...   1571.061          s          Eng-NA
# 460057              9           9  ...   1576.861          s          Eng-NA
# 460058              3           3  ...   1577.373          s          Eng-NA
# 460059    -2147483648           4  ...   1581.430          s          Eng-NA
# 460060              1           1  ...   1583.370          s          Eng-NA
#
#        collection_id corpus_id speaker_id target_child_id  transcript_id  \
# 0                 21       336      23475           23471          43208
# 1                 21       336      23473           23471          43208
# 2                 21       336      23473           23471          43208
# 3                 21       336      23473           23471          43208
# 4                 21       336      23475           23471          43208
# ...              ...       ...        ...             ...            ...
# 460056            21       336      23530           23530          43562
# 460057            21       336      23530           23530          43562
# 460058            21       336      23534           23530          43562
# 460059            21       336      23530           23530          43562
# 460060            21       336      23530           23530          43562
#
#                                     filename  bin_label
# 0          Eng-NA/Providence/Alex/010427.xml      12-18
# 1          Eng-NA/Providence/Alex/010427.xml      12-18
# 2          Eng-NA/Providence/Alex/010427.xml      12-18
# 3          Eng-NA/Providence/Alex/010427.xml      12-18
# 4          Eng-NA/Providence/Alex/010427.xml      12-18
# ...                                      ...        ...
# 460056  Eng-NA/Providence/William/020822.xml      30-36
# 460057  Eng-NA/Providence/William/020822.xml      30-36
# 460058  Eng-NA/Providence/William/020822.xml      30-36
# 460059  Eng-NA/Providence/William/020822.xml      30-36
# 460060  Eng-NA/Providence/William/020822.xml      30-36
#
# [460061 rows x 30 columns]

# %%
pd.merge(full_merge, trans_labelled, on='transcript_id', how='left').drop(columns = ['index_y','target_child_age_y','bin_label_y'])
# Out:
#         index_x        id                                         gloss  \
# 0             0  17264832                    where do you want me to go
# 1             1  17264840  anywhere you'll feel comfortable um anywhere
# 2             2  17264848                          please don't do that
# 3             3  17264856                                       this is
# 4             4  17264864        go into the kitchen and check in about
# ...         ...       ...                                           ...
# 460056    56367  17753088                                           xxx
# 460057    56368  17753090       xxx my lion Daddy I don't bring my lion
# 460058    56369  17753091                                come here Will
# 460059    56370  17753092                               yyy yyy yyy yyy
# 460060    56371  17753093                                          roar
#
#                                           stem  \
# 0                   where do you want me to go
# 1           anywhere you feel comfort anywhere
# 2                            please do do that
# 3                                      this be
# 4       go into the kitchen and check in about
# ...                                        ...
# 460056
# 460057        my lion Daddy I do bring my lion
# 460058                          come here Will
# 460059
# 460060                                    roar
#
#                              actual_phonology  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 460056                                      *
# 460057  * mə laɪɛn dædi aɪ don brɪŋ maɪ laɪɛn
# 460058
# 460059                      dɜ˞r dɛ dɜ˞r dɜ˞r
# 460060                                    rær
#
#                                   model_phonology               type language  \
# 0                                                           question      eng
# 1                                                        declarative      eng
# 2                                                        declarative      eng
# 3                                                  self interruption      eng
# 4                                                  self interruption      eng
# ...                                           ...                ...      ...
# 460056                                          *        declarative      eng
# 460057  * maɪ laɪən dædiː aɪ doʊnt bɹɪŋ maɪ laɪən        declarative      eng
# 460058                                                   declarative      eng
# 460059                                    * * * *        declarative      eng
# 460060                                        ɹɔɹ        declarative      eng
#
#         num_morphemes  num_tokens  ...  collection_name collection_id  \
# 0                   7           7  ...           Eng-NA            21
# 1                   8           6  ...           Eng-NA            21
# 2                   5           4  ...           Eng-NA            21
# 3                   3           2  ...           Eng-NA            21
# 4                   8           8  ...           Eng-NA            21
# ...               ...         ...  ...              ...           ...
# 460056    -2147483648           1  ...           Eng-NA            21
# 460057              9           9  ...           Eng-NA            21
# 460058              3           3  ...           Eng-NA            21
# 460059    -2147483648           4  ...           Eng-NA            21
# 460060              1           1  ...           Eng-NA            21
#
#        corpus_id speaker_id target_child_id transcript_id  \
# 0            336      23475           23471         43208
# 1            336      23473           23471         43208
# 2            336      23473           23471         43208
# 3            336      23473           23471         43208
# 4            336      23475           23471         43208
# ...          ...        ...             ...           ...
# 460056       336      23530           23530         43562
# 460057       336      23530           23530         43562
# 460058       336      23534           23530         43562
# 460059       336      23530           23530         43562
# 460060       336      23530           23530         43562
#
#                                     filename  bin_label_x target_child_name_y  \
# 0          Eng-NA/Providence/Alex/010427.xml        12-18                Alex
# 1          Eng-NA/Providence/Alex/010427.xml        12-18                Alex
# 2          Eng-NA/Providence/Alex/010427.xml        12-18                Alex
# 3          Eng-NA/Providence/Alex/010427.xml        12-18                Alex
# 4          Eng-NA/Providence/Alex/010427.xml        12-18                Alex
# ...                                      ...          ...                 ...
# 460056  Eng-NA/Providence/William/020822.xml        30-36             William
# 460057  Eng-NA/Providence/William/020822.xml        30-36             William
# 460058  Eng-NA/Providence/William/020822.xml        30-36             William
# 460059  Eng-NA/Providence/William/020822.xml        30-36             William
# 460060  Eng-NA/Providence/William/020822.xml        30-36             William
#
#         split
# 0          TR
# 1          TR
# 2          TR
# 3          TR
# 4          TR
# ...       ...
# 460056     TR
# 460057     TR
# 460058     TR
# 460059     TR
# 460060     TR
#
# [460061 rows x 32 columns]

# %%
''' 

partitions_with_splits = []
for binlabel in labels:
    bin_df = full_merge[full_merge['bin_label'] == binlabel]
    nrows = len(bin_df)
    ntr = round(nrows*0.8)
    nva = round(nrows*0.1)
    nte = nrows - ntr - nva
    lab = ["TR"] * ntr + ["VA"] * nva + ["TE"] * nte
    lab_array = np.array(lab)
    np.random.shuffle(lab_array)
    bin_df['split'] = lab_array
    partitions_with_splits.append(bin_df)



#what about seed?
'''
# Out:
# ' \n\npartitions_with_splits = []\nfor binlabel in labels:\n    bin_df = full_merge[full_merge[\'bin_label\'] == binlabel]\n    nrows = len(bin_df)\n    ntr = round(nrows*0.8)\n    nva = round(nrows*0.1)\n    nte = nrows - ntr - nva\n    lab = ["TR"] * ntr + ["VA"] * nva + ["TE"] * nte\n    lab_array = np.array(lab)\n    np.random.shuffle(lab_array)\n    bin_df[\'split\'] = lab_array\n    partitions_with_splits.append(bin_df)\n\n\n\n#what about seed?\n'

# %%
'''partitions_with_splits[0]'''
# Out:
# 'partitions_with_splits[0]'

# %%
'''full_merge_with_split = pd.concat([d for d in partitions_with_splits]).reset_index()'''
# Out:
# 'full_merge_with_split = pd.concat([d for d in partitions_with_splits]).reset_index()'

# %%
full_merge_with_split = pd.merge(full_merge, trans_labelled, on='transcript_id', how='left').drop(columns = ['index_y','target_child_age_y','bin_label_y','target_child_name_y'])

# %%
full_merge_with_split.rename(columns={'target_child_age_x': 'target_child_age', 'bin_label_x': 'bin_label', 'target_child_name_x':'target_child_name'}, inplace=True)
full_merge_with_split.columns
# Out:
# Index(['index_x', 'id', 'gloss', 'stem', 'actual_phonology', 'model_phonology',
#        'type', 'language', 'num_morphemes', 'num_tokens', 'utterance_order',
#        'corpus_name', 'part_of_speech', 'speaker_code', 'speaker_name',
#        'speaker_role', 'target_child_name', 'target_child_age',
#        'target_child_sex', 'media_start', 'media_end', 'media_unit',
#        'collection_name', 'collection_id', 'corpus_id', 'speaker_id',
#        'target_child_id', 'transcript_id', 'filename', 'bin_label', 'split'],
#       dtype='object')

# %%
full_merge_with_split.to_csv("providence_split.csv", index=False)

# %% [markdown]
# SPLIT | CHILD | AGE DURING RECORDING (days -- continuous) | # OF TOKENS CHI | # OF TOKENS ADULT

# %%
full_merge_with_split['num_tokens']
# Out:
# 0         7
# 1         6
# 2         4
# 3         2
# 4         8
#          ..
# 460056    1
# 460057    9
# 460058    3
# 460059    4
# 460060    1
# Name: num_tokens, Length: 460061, dtype: int32

# %%
agg_func  = {'num_tokens':['sum']}
full_merge_with_split.groupby(['split','target_child_name','speaker_role']).agg(agg_func)
# Out:
#                                      num_tokens
#                                             sum
# split target_child_name speaker_role
# TE    Alex              Adult                36
#                         Environment          38
#                         Father               36
#                         Grandmother         565
#                         Investigator        299
# ...                                         ...
# VA    Violet            Mother             6013
#                         Target_Child       2349
#       William           Investigator         63
#                         Mother             7820
#                         Target_Child       1660
#
# [121 rows x 1 columns]

# %% [markdown]
# ### Possible speaker codes:

# %%
full_merge['speaker_role'].unique()
# Out:
# array(['Investigator', 'Mother', 'Target_Child', 'Environment', 'Media',
#        'Adult', 'Father', 'Grandmother', 'Unidentified', 'Relative',
#        'Grandfather', 'Visitor', 'Friend', 'Brother', 'Sister'],
#       dtype=object)

# %%
full_train = full_merge_with_split[full_merge_with_split['split']=='TR']
full_valid = full_merge_with_split[full_merge_with_split['split']=='VA']
full_test = full_merge_with_split[full_merge_with_split['split']=='TE']

# %%
full_train.columns
# Out:
# Index(['index_x', 'id', 'gloss', 'stem', 'actual_phonology', 'model_phonology',
#        'type', 'language', 'num_morphemes', 'num_tokens', 'utterance_order',
#        'corpus_name', 'part_of_speech', 'speaker_code', 'speaker_name',
#        'speaker_role', 'target_child_name', 'target_child_age',
#        'target_child_sex', 'media_start', 'media_end', 'media_unit',
#        'collection_name', 'collection_id', 'corpus_id', 'speaker_id',
#        'target_child_id', 'transcript_id', 'filename', 'bin_label', 'split'],
#       dtype='object')

# %% [markdown]
# ## Train set

# %%
d_train  = (full_train.groupby(['target_child_name','target_child_age']).agg({'num_tokens':['sum']})).reset_index()

# %%
d_train
# Out:
#     target_child_name target_child_age num_tokens
#                                               sum
# 0                Alex        16.887410       2330
# 1                Alex        17.394608       2653
# 2                Alex        19.230374       3215
# 3                Alex        19.854617       3655
# 4                Alex        20.821783       3205
# ..                ...              ...        ...
# 265           William        37.493583       5990
# 266           William        37.822132       4593
# 267           William        38.690733       6264
# 268           William        39.165075       4999
# 269           William        39.822173       2763
#
# [270 rows x 3 columns]

# %%
import warnings
from pandas.errors import SettingWithCopyWarning
warnings.filterwarnings('ignore', category=SettingWithCopyWarning)
rolling_list=[]
for child in child_names:
    sub_df = d_train[d_train['target_child_name'] == child]
    sub_df['rolling'] = sub_df['num_tokens']['sum'].rolling(window=7, min_periods=1).mean() 
    rolling_list.append(sub_df)

master_rolling =  pd.concat([d for d in rolling_list]).reset_index()

# %%
trainbychild = sns.FacetGrid(d_train, col ='target_child_name', height=3, col_wrap=3)
trainbychild.set(xticks = np.arange(10, 51, 5))
trainbychild.map(sns.lineplot, 'target_child_age', 'num_tokens').add_legend() 
trainbychild.fig.suptitle('Number of tokens v/s Age (months) during expt.', fontsize=14)
trainbychild.fig.subplots_adjust(top=0.9)
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Below graph uses smoothing by taking rolling averages with a window size of 7

# %%
trainbychild = sns.FacetGrid(master_rolling, col ='target_child_name', height=3, col_wrap=3)
trainbychild.set(xticks = np.arange(10, 51, 5))
trainbychild.map(sns.lineplot, 'target_child_age', 'rolling').add_legend() 
trainbychild.fig.suptitle('Number of tokens (rolling avg.) v/s Age (months) during expt.', fontsize=14)
trainbychild.fig.subplots_adjust(top=0.9)
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='target_child_age', y=('num_tokens', 'sum'), hue='target_child_name', data=d_train,palette='bright')
plt.xticks(ticks=np.arange(10, 50, 2))  # Set the positions only
plt.yticks(ticks=np.arange(0, 12000, 500))  # Set the positions only
plt.xlabel('Age in months')
plt.ylabel('Total # of tokens')
plt.title('TRAIN DATA : tokens v/s age')
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'TRAIN DATA : tokens v/s age')

# %% [markdown]
# ## Validate set

# %%
d_valid  = (full_valid.groupby(['target_child_name','target_child_age']).agg({'num_tokens':['sum']})).reset_index()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='target_child_age', y=('num_tokens', 'sum'), hue='target_child_name', data=d_valid,palette='bright')
plt.xticks(ticks=np.arange(10, 50, 2))  # Set the positions only
plt.yticks(ticks=np.arange(0, 1500, 100))  # Set the positions only
plt.xlabel('Age in months')
plt.ylabel('Total # of tokens')
plt.title('VALIDATION DATA : tokens v/s age')
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'VALIDATION DATA : tokens v/s age')

# %% [markdown]
# ## Test set

# %%
d_test  = (full_test.groupby(['target_child_name','target_child_age']).agg({'num_tokens':['sum']})).reset_index()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='target_child_age', y=('num_tokens', 'sum'), hue='target_child_name', data=d_test,palette='bright')
plt.xticks(ticks=np.arange(10, 50, 2))  # Set the positions only
plt.yticks(ticks=np.arange(0, 1500, 200))  # Set the positions only
plt.xlabel('Age in months')
plt.ylabel('Total # of tokens')
plt.title('TEST DATA : tokens v/s age')
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'TEST DATA : tokens v/s age')

# %%
fig, axs = plt.subplots(1, 3, figsize=(34, 10))  # 1 row, 3 columns

# Plot 1
sns.lineplot(x='target_child_age', y=('num_tokens', 'sum'), hue='target_child_name', data=d_train,palette='bright', ax=axs[0])
axs[0].set_title('TRAIN')
axs[0].set_xlabel('Age in months')
axs[0].set_ylabel('Total # of tokens')

# Plot 2
sns.lineplot(x='target_child_age', y=('num_tokens', 'sum'), hue='target_child_name', data=d_valid,palette='bright', ax=axs[1])
axs[1].set_title('VALIDATION')
axs[1].set_xlabel('Age in months')
axs[1].set_ylabel('Total # of tokens')

# Plot 3
sns.lineplot(x='target_child_age', y=('num_tokens', 'sum'), hue='target_child_name', data=d_test,palette='bright', ax=axs[2])  
axs[2].set_title('TEST')
axs[2].set_xlabel('Age in months')
axs[2].set_ylabel('Total # of tokens')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Automating train, validate, test graphs for no. of tokens v/s age

# %%
import warnings
from pandas.errors import SettingWithCopyWarning
#from pandas.errors import FutureWarning
warnings.filterwarnings('ignore', category=SettingWithCopyWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

labels = [0,1,2]
colors = ['blue','green','violet']
for label in labels:
    if label == 0:
        dataset = full_train
        title = "TRAIN SET"
    elif label == 1:
        dataset = full_valid
        title = "VALIDATION SET"
    else:
        dataset = full_test
        title = "TEST SET"
    
    d_train  = (dataset.groupby(['target_child_name','target_child_age']).agg({'num_tokens':['sum']})).reset_index()


    rolling_list=[]
    for child in child_names:
        sub_df = d_train[d_train['target_child_name'] == child]
        sub_df['No. of tokens'] = sub_df['num_tokens']['sum'].rolling(window=4, min_periods=1).mean() 
        rolling_list.append(sub_df)
    
    master_rolling =  pd.concat([d for d in rolling_list]).reset_index()

    trainbychild = sns.FacetGrid(d_train, col ='target_child_name', height=3, col_wrap=3)
    trainbychild.set(xticks = np.arange(10, 51, 5))
    trainbychild.map(sns.lineplot, 'target_child_age', 'num_tokens',color=colors[label]).add_legend() 
    trainbychild.fig.suptitle(title+' :Number of tokens v/s Age (months) during expt.', fontsize=14)
    trainbychild.fig.subplots_adjust(top=0.9) 
    plt.show()
    print('\n')

    trainbychild = sns.FacetGrid(master_rolling, col ='target_child_name', height=3, col_wrap=3)
    trainbychild.set(xticks = np.arange(10, 51, 5))
    trainbychild.map(sns.lineplot, 'target_child_age', 'No. of tokens', color=colors[label]).add_legend() 
    trainbychild.fig.suptitle(title+' :Number of tokens (rolling avg.) v/s Age (months) during expt.', fontsize=14)
    trainbychild.fig.subplots_adjust(top=0.9)  
    trainbychild.set_titles(template = '{col_name}')
     
    plt.savefig(title+'_granular_plot.png')
    plt.show()
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Drawing KDE plots now

# %%
df_for_facet  = (dataset.groupby(['target_child_name','target_child_age']).agg({'num_tokens':['sum']})).reset_index()
unrolled_df = df_for_facet.loc[df_for_facet.index.repeat(df_for_facet['num_tokens']['sum'])].reset_index(drop=True)

# %%
unrolled_df
# Out:
#        target_child_name target_child_age num_tokens
#                                                  sum
# 0                   Alex        17.854576       2755
# 1                   Alex        17.854576       2755
# 2                   Alex        17.854576       2755
# 3                   Alex        17.854576       2755
# 4                   Alex        17.854576       2755
# ...                  ...              ...        ...
# 321440           William        40.592209       5514
# 321441           William        40.592209       5514
# 321442           William        40.592209       5514
# 321443           William        40.592209       5514
# 321444           William        40.592209       5514
#
# [321445 rows x 3 columns]

# %%
import warnings
from pandas.errors import SettingWithCopyWarning
#from pandas.errors import FutureWarning
warnings.filterwarnings('ignore', category=SettingWithCopyWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

labels = [0,1,2]
colors = ['blue','green','red']
for label in labels:
    if label == 0:
        dataset = full_train
        title = "TRAIN SET"
    elif label == 1:
        dataset = full_valid
        title = "VALIDATION SET"
    else:
        dataset = full_test
        title = "TEST SET"
    
    df_for_facet  = (dataset.groupby(['target_child_name','target_child_age']).agg({'num_tokens':['sum']})).reset_index()
    unrolled_df = df_for_facet.loc[df_for_facet.index.repeat(df_for_facet['num_tokens']['sum'])].reset_index(drop=True)
    
    '''
    rolling_list=[]
    
    for child in child_names:
        sub_df = df_for_facet[df_for_facet['target_child_name'] == child]
        sub_df['No. of tokens'] = sub_df['num_tokens']['sum'].rolling(window=4, min_periods=1).mean() 
        rolling_list.append(sub_df)
    '''

    trainbychild = sns.FacetGrid(unrolled_df, col ='target_child_name', height=3, col_wrap=3)
    trainbychild.set(xticks = np.arange(6, 51, 6))
    trainbychild.map(sns.kdeplot, 'target_child_age',  fill=True,bw_method=0.2,color=colors[label]).add_legend() 
    trainbychild.fig.suptitle(title+': Density of tokens v/s Age (months)', fontsize=14)
    trainbychild.fig.subplots_adjust(top=0.9) 
    trainbychild.set_titles(template = '{col_name}')
 
    print('\n')
     
    plt.savefig(title+'unrolled_kde_plot.png')
    plt.show()
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## CHILD-WISE ANALYSIS

# %%
agg_func  = {'num_tokens':['sum']}
bar_master = (full_merge_with_split.groupby(['target_child_name','speaker_role','split']).agg(agg_func)).reset_index()

# %%
bar_master
# Out:
#     target_child_name  speaker_role split num_tokens
#                                                  sum
# 0                Alex         Adult    TE         36
# 1                Alex         Adult    TR       1148
# 2                Alex   Environment    TE         38
# 3                Alex   Environment    TR        655
# 4                Alex   Environment    VA        536
# ..                ...           ...   ...        ...
# 116           William        Sister    TR        157
# 117           William  Target_Child    TE      11141
# 118           William  Target_Child    TR      33707
# 119           William  Target_Child    VA       1660
# 120           William       Visitor    TR        596
#
# [121 rows x 4 columns]

# %%
bar_master_alex = bar_master[bar_master['target_child_name']=='Alex']

# %%
alex_sums = bar_master_alex.groupby('speaker_role')['num_tokens'].sum().reset_index()
alex_merged = pd.merge(bar_master_alex, alex_sums, on='speaker_role')
# Out:
# /tmp/ipykernel_3605748/4273109649.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   alex_merged = pd.merge(bar_master_alex, alex_sums, on='speaker_role')

# %%
bar_master_alex['proportion'] = alex_merged['num_tokens_x'] / alex_merged['num_tokens_y']

# %%
bar_master_alex
# Out:
#    target_child_name  speaker_role split num_tokens proportion
#                                                 sum
# 0               Alex         Adult    TE         36   0.030405
# 1               Alex         Adult    TR       1148   0.969595
# 2               Alex   Environment    TE         38   0.030919
# 3               Alex   Environment    TR        655   0.532954
# 4               Alex   Environment    VA        536   0.436127
# 5               Alex        Father    TE         36   0.031915
# 6               Alex        Father    TR       1068   0.946809
# 7               Alex        Father    VA         24   0.021277
# 8               Alex   Grandfather    TR       1078   1.000000
# 9               Alex   Grandmother    TE        565   0.073914
# 10              Alex   Grandmother    TR       6519   0.852826
# 11              Alex   Grandmother    VA        560   0.073260
# 12              Alex  Investigator    TE        299   0.246091
# 13              Alex  Investigator    TR        882   0.725926
# 14              Alex  Investigator    VA         34   0.027984
# 15              Alex         Media    TE        129   0.071866
# 16              Alex         Media    TR       1637   0.911978
# 17              Alex         Media    VA         29   0.016156
# 18              Alex        Mother    TE      24902   0.164653
# 19              Alex        Mother    TR     115498   0.763679
# 20              Alex        Mother    VA      10839   0.071668
# 21              Alex      Relative    TE        152   1.000000
# 22              Alex  Target_Child    TE      11811   0.185332
# 23              Alex  Target_Child    TR      47343   0.742880
# 24              Alex  Target_Child    VA       4575   0.071788
# 25              Alex  Unidentified    TE          1   0.012987
# 26              Alex  Unidentified    TR         76   0.987013

# %%
sns.barplot(x='speaker_role', y=('num_tokens','sum'), hue='split', data=bar_master_alex)
plt.ylim(0, 20000)
plt.xticks(rotation=35) 
plt.xlabel('Speaker')
plt.ylabel('Total # of tokens')
plt.title('ALEX (capped at 20k tokens for visibility)')
# Out:
# Text(0.5, 1.0, 'ALEX (capped at 20k tokens for visibility)')

# %%
def create_child_graph(name):
    bar_master_alex = bar_master[bar_master['target_child_name']==name]
    sns.barplot(x='speaker_role', y=('num_tokens','sum'), hue='split', data=bar_master_alex)
    plt.ylim(0, 20000)
    plt.xticks(rotation=35) 
    plt.xlabel('Speaker')
    plt.ylabel('Total # of tokens')
    plt.title(name + '(capped at 20k tokens for visibility)')
    plt.show()

for child in child_names:
    create_child_graph(child)

# %% [markdown]
# ## Child-wise analysis (only considering child and mother/father)

# %%
child_wise_master = (full_merge_with_split.groupby(['target_child_name','speaker_code','split']).agg(agg_func)).reset_index()
child_wise_master
# Out:
#     target_child_name speaker_code split num_tokens
#                                                 sum
# 0                Alex          AD1    TR         29
# 1                Alex          AD2    TR        309
# 2                Alex          ADU    TE         36
# 3                Alex          ADU    TR        810
# 4                Alex          CHI    TE      11811
# ..                ...          ...   ...        ...
# 141           William          SIS    TR        157
# 142           William          TOY    TE        166
# 143           William          TOY    TR        745
# 144           William          VI1    TR        594
# 145           William          VI2    TR          2
#
# [146 rows x 4 columns]

# %%
relevant_codes = ['CHI','MOT']

# %%
df_fmc = child_wise_master[child_wise_master['speaker_code'].isin(relevant_codes)]

# %%
warnings.filterwarnings('ignore', category=SettingWithCopyWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
graph_speaker = sns.FacetGrid(df_fmc, col ='split', height=3, row='speaker_code',hue='speaker_code')
#trainbychild.set(xticks = np.arange(10, 51, 5))
graph_speaker.map(sns.barplot, 'target_child_name', 'num_tokens',order=child_names,errorbar=None).add_legend() 
graph_speaker.fig.suptitle('Number of tokens from each speaker, per split set, per child', fontsize=14)
graph_speaker.fig.subplots_adjust(top=0.851) 
for ax in graph_speaker.axes.flatten():
    ax.set_xticklabels(child_names, rotation=35, ha='right')
graph_speaker.set_ylabels(label = 'No. of tokens')
graph_speaker.set_titles(template = 'Split: {col_name}, Speaker : {row_name}')
plt.savefig('speakercodes_facet.png', bbox_inches='tight')
plt.show()
# Out:
# /cm/shared/openmind8/anaconda/3-2023.09-0/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
trans_ages[trans_ages['target_child_name']=='William']
# Out:
#         transcript_id  target_child_age target_child_name bin_label
# 403689          43530         16.887410           William     12-18
# 404906          43535         19.591778           William     18-24
# 405380          43538         20.953202           William     18-24
# 406109          43542         22.394710           William     18-24
# 406306          43541         23.000472           William     18-24
# 406312          43540         21.887513           William     18-24
# 406377          43533         18.624612           William     18-24
# 406512          43543         23.493296           William     18-24
# 406531          43531         16.394587           William     12-18
# 409120          43547         25.887595           William     24-30
# 409210          43532         18.164644           William     18-24
# 409211          43537         20.460379           William     18-24
# 409212          43539         21.394690           William     18-24
# 411861          43546         25.296207           William     24-30
# 412424          43536         20.066120           William     18-24
# 414368          43544         24.394751           William     24-30
# 418328          43555         29.526274           William     24-30
# 420398          43545         24.920430           William     24-30
# 420430          43549         26.690486           William     24-30
# 421890          43534         19.263229           William     18-24
# 424442          43556         29.953387           William     24-30
# 424552          43552         28.099140           William     24-30
# 425275          43563         33.164952           William     30-36
# 427951          43557         30.854843           William     30-36
# 428009          43561         32.263496           William     30-36
# 428010          43554         29.000595           William     24-30
# 428011          43565         35.460687           William     30-36
# 429439          43564         35.000719           William     30-36
# 431547          43551         27.624797           William     24-30
# 432516          43567         36.920676           William     36-42
# 432517          43559         31.263476           William     30-36
# 432518          43558         30.394875           William     30-36
# 436693          43571         39.165075           William     36-42
# 436694          43548         26.296228           William     24-30
# 436695          43570         38.690733           William     36-42
# 443559          43568         37.493583           William     36-42
# 444642          43560         31.854864           William     30-36
# 444643          43573         40.592209           William     36-42
# 446588          43566         36.362143           William     36-42
# 446930          43553         28.526253           William     24-30
# 447995          43572         39.822173           William     36-42
# 448854          43569         37.822132           William     36-42
# 454765          43550         27.230539           William     24-30
# 459279          43562         32.723465           William     30-36

# %%
trans_labelled[(trans_labelled['target_child_name']=='William') & (trans_labelled['bin_label']=='18-24')]
# Out:
#       index  transcript_id  target_child_age target_child_name bin_label split
# 130  404906          43535         19.591778           William     18-24    TR
# 131  405380          43538         20.953202           William     18-24    TR
# 132  406109          43542         22.394710           William     18-24    TE
# 133  406306          43541         23.000472           William     18-24    TR
# 134  406312          43540         21.887513           William     18-24    TR
# 135  406377          43533         18.624612           William     18-24    TR
# 136  406512          43543         23.493296           William     18-24    VA
# 137  409210          43532         18.164644           William     18-24    TR
# 138  409211          43537         20.460379           William     18-24    TR
# 139  409212          43539         21.394690           William     18-24    TE
# 140  412424          43536         20.066120           William     18-24    TR
# 141  421890          43534         19.263229           William     18-24    TR
